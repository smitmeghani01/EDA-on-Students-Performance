# %% [markdown]
# # EDA - Exploratory Data Analysis

# %% [markdown]
# # Importing Packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading the dataset

# %%
df_train = pd.read_csv("students_train.csv")
df_test = pd.read_csv("students_test.csv")
# data = pd.read_csv("https://raw.githubusercontent.com/rahulinchal/EDA-on-StudentsPerformance/main/StudentsPerformance.csv")

# %% [markdown]
# # Head =  first 5 rows

# %%
df_train.head()
# Out:
#    id  gender race/ethnicity parental level of education         lunch  \
# 0   1  female        group B           bachelor's degree      standard
# 1   2  female        group C                some college      standard
# 2   3  female        group B             master's degree      standard
# 3   4    male        group A          associate's degree  free/reduced
# 4   5    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Tail = last 5 rows

# %%
df_train.tail()
# Out:
#       id  gender race/ethnicity parental level of education         lunch  \
# 693  694  female        group D          associate's degree      standard
# 694  695  female        group C            some high school      standard
# 695  696  female        group D                some college  free/reduced
# 696  697  female        group C          associate's degree      standard
# 697  698  female        group A           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 693                    none          77             77             73
# 694                    none          49             63             56
# 695                    none          79             89             86
# 696               completed          75             82             90
# 697                    none          59             72             70

# %% [markdown]
# # Data Statistics

# %%
df_train.sample(10)
# Out:
#       id  gender race/ethnicity parental level of education         lunch  \
# 127  128    male        group D                some college      standard
# 186  187    male        group E                 high school      standard
# 136  137    male        group B            some high school      standard
# 173  174  female        group C          associate's degree      standard
# 674  675  female        group D                 high school      standard
# 285  286    male        group B          associate's degree      standard
# 693  694  female        group D          associate's degree      standard
# 302  303  female        group C          associate's degree      standard
# 59    60  female        group C            some high school  free/reduced
# 691  692  female        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 127               completed          65             77             74
# ...

# %%
df_train.shape
# Out:
# (698, 9)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           698 non-null    int64
#  1   gender                       698 non-null    object
#  2   race/ethnicity               698 non-null    object
#  3   parental level of education  698 non-null    object
#  4   lunch                        698 non-null    object
#  5   test preparation course      698 non-null    object
#  6   math score                   698 non-null    int64
#  7   reading score                698 non-null    int64
#  8   writing score                698 non-null    int64
# dtypes: int64(4), object(5)
# memory usage: 49.2+ KB

# %%
df_train.describe()
# Out:
#               id  math score  reading score  writing score
# count  698.00000  698.000000     698.000000     698.000000
# mean   349.50000   66.022923      69.071633      67.836676
# std    201.63953   15.041770      14.599995      15.196531
# min      1.00000    0.000000      17.000000      10.000000
# 25%    175.25000   57.000000      59.000000      57.000000
# 50%    349.50000   66.000000      70.000000      69.000000
# 75%    523.75000   76.750000      79.000000      78.000000
# max    698.00000  100.000000     100.000000     100.000000

# %%
df_train.nunique()
# Out:
# id                             698
# gender                           2
# race/ethnicity                   5
# parental level of education      6
# lunch                            2
# test preparation course          2
# math score                      78
# reading score                   72
# writing score                   76
# dtype: int64

# %%
df_train["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df_train["race/ethnicity"].value_counts()
# Out:
# group C    229
# group D    185
# group B    133
# group E     90
# group A     61
# Name: race/ethnicity, dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
# No of males and females
sns.countplot(x='gender', data=df_train)

# %%
# How many students of each gender completed course?
sns.countplot(x='gender',hue="test preparation course",data=df_train)

# %%
# Students of which age group are good and well prepared with math?
sns.barplot(x='race/ethnicity',y="math score",data=df_train)

# %%
# How is the reading score distribution amount the students?
sns.histplot(df_train['reading score'],color='red')

# %%
df_train.head()
# Out:
#    id  gender race/ethnicity parental level of education         lunch  \
# 0   1  female        group B           bachelor's degree      standard
# 1   2  female        group C                some college      standard
# 2   3  female        group B             master's degree      standard
# 3   4    male        group A          associate's degree  free/reduced
# 4   5    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Data Cleaning

# %%
#Step 2. Quick data cleaning and pre-processing

# Drop race/ethnictity and parental level of education column
# Binary encode Sex column

# %%
# Dropping tables
df_tain = df_train.drop(["race/ethnicity","parental level of education"], axis =1)

# %% [markdown]
# # Correaltion = Mutual relationship

# %%
correlation = df_train.corr()

# %%
sns.heatmap(correlation , annot = True)

# %%
sns.pairplot(df_train)

# %%
sns.relplot(x= "math score", y = "reading score", hue = "gender", data = df_train)
